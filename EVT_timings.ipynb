# %%
import pandas as pd

# %%
registry_path = '/Users/jk1/Library/CloudStorage/OneDrive-unige.ch/stroke_research/geneva_stroke_unit_dataset/data/stroke_registry/post_hoc_modified/stroke_registry_post_hoc_modified.xlsx'

# %%
registry_df = pd.read_excel(registry_path)

# %%
registry_df

# %%
registry_df['Door to groin puncture (min.)'].describe()

# %%
# histogram
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
# limit 0 -300 minutes
sns.histplot(registry_df['Door to groin puncture (min.)'].dropna(), bins=300, kde=True, binrange=(0, 300))
plt.title('Distribution of Door to Groin Puncture Time')
plt.xlabel('Door to Groin Puncture Time (min)')
plt.ylabel('Frequency')
plt.xlim(0, 300)
plt.show()
